# %%
pip install spotipy --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: spotipy in c:\users\vedan\appdata\roaming\python\python312\site-packages (2.24.0)
# Requirement already satisfied: redis>=3.5.3 in c:\users\vedan\appdata\roaming\python\python312\site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in c:\python312\lib\site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in c:\python312\lib\site-packages (from spotipy) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\python312\lib\site-packages (from requests>=2.25.0->spotipy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\python312\lib\site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python312\lib\site-packages (from requests>=2.25.0->spotipy) (2024.8.30)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="<Enter Your Client ID here>", client_secret="<Enter Your Client Secret here>")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/6VOedaf3eNWDOVpa9Qdlvg"

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]
print(playlist_URI)
# Out:
# 6VOedaf3eNWDOVpa9Qdlvg

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items']
# Out:
# [{'added_at': '2024-02-23T14:40:21Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/6DptPhwLku8xvWBodULnC6',
#     'id': '6DptPhwLku8xvWBodULnC6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c658105590edfb75e0714a90',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c658105590edfb75e0714a90',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c658105590edfb75e0714a90',
#       'width': 64}],
#     'name': 'Orquestra Maldita',
#     'release_date': '2023-06-15',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:6DptPhwLku8xvWBodULnC6',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rt96VXGtEgD4uSOJ6B69H'},
#       'href': 'https://api.spotify.com/v1/artists/3rt96VXGtEgD4uSOJ6B69H',
#       'id': '3rt96VXGtEgD4uSOJ6B69H',
#       'name': 'TRASHXRL',
#       'type': 'artist',
#       'uri': 'spotify:artist:3rt96VXGtEgD4uSOJ6B69H'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3l4fsEzoeabsET7ddv0lZW'},
#       'href': 'https://api.spotify.com/v1/artists/3l4fsEzoeabsET7ddv0lZW',
#       'id': '3l4fsEzoeabsET7ddv0lZW',
#       'name': 'Mc Delux',
#       'type': 'artist',
#       'uri': 'spotify:artist:3l4fsEzoeabsET7ddv0lZW'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6DptPhwLku8xvWBodULnC6'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rt96VXGtEgD4uSOJ6B69H'},
#      'href': 'https://api.spotify.com/v1/artists/3rt96VXGtEgD4uSOJ6B69H',
#      'id': '3rt96VXGtEgD4uSOJ6B69H',
#      'name': 'TRASHXRL',
#      'type': 'artist',
#      'uri': 'spotify:artist:3rt96VXGtEgD4uSOJ6B69H'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3l4fsEzoeabsET7ddv0lZW'},
#      'href': 'https://api.spotify.com/v1/artists/3l4fsEzoeabsET7ddv0lZW',
#      'id': '3l4fsEzoeabsET7ddv0lZW',
#      'name': 'Mc Delux',
#      'type': 'artist',
#      'uri': 'spotify:artist:3l4fsEzoeabsET7ddv0lZW'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 119777,
#    'external_ids': {'isrc': 'BX7272300515'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7hcagAQDiI0TgUOv337NIr'},
#    'href': 'https://api.spotify.com/v1/tracks/7hcagAQDiI0TgUOv337NIr',
#    'id': '7hcagAQDiI0TgUOv337NIr',
#    'name': 'Orquestra Maldita',
#    'popularity': 72,
#    'uri': 'spotify:track:7hcagAQDiI0TgUOv337NIr',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-02-23T14:51:11Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/0ZE5fMneYtdl93X1GHqxSH',
#     'id': '0ZE5fMneYtdl93X1GHqxSH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bac8b6324326cf93bb91eaf7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bac8b6324326cf93bb91eaf7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bac8b6324326cf93bb91eaf7',
#       'width': 64}],
#     'name': 'BYE BYE!',
#     'release_date': '2024-01-12',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0ZE5fMneYtdl93X1GHqxSH',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sj3P8OH8O5aVmey1C2mf4'},
#       'href': 'https://api.spotify.com/v1/artists/5sj3P8OH8O5aVmey1C2mf4',
#       'id': '5sj3P8OH8O5aVmey1C2mf4',
#       'name': 'PXRKX',
#       'type': 'artist',
#       'uri': 'spotify:artist:5sj3P8OH8O5aVmey1C2mf4'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5hfVobwxTC73whNVhzwlcP'},
#       'href': 'https://api.spotify.com/v1/artists/5hfVobwxTC73whNVhzwlcP',
#       'id': '5hfVobwxTC73whNVhzwlcP',
#       'name': 'RZXT!',
#       'type': 'artist',
#       'uri': 'spotify:artist:5hfVobwxTC73whNVhzwlcP'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0ZE5fMneYtdl93X1GHqxSH'},
#     'total_tracks': 3},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5sj3P8OH8O5aVmey1C2mf4'},
#      'href': 'https://api.spotify.com/v1/artists/5sj3P8OH8O5aVmey1C2mf4',
#      'id': '5sj3P8OH8O5aVmey1C2mf4',
#      'name': 'PXRKX',
#      'type': 'artist',
#      'uri': 'spotify:artist:5sj3P8OH8O5aVmey1C2mf4'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5hfVobwxTC73whNVhzwlcP'},
#      'href': 'https://api.spotify.com/v1/artists/5hfVobwxTC73whNVhzwlcP',
#      'id': '5hfVobwxTC73whNVhzwlcP',
#      'name': 'RZXT!',
#      'type': 'artist',
#      'uri': 'spotify:artist:5hfVobwxTC73whNVhzwlcP'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 112000,
#    'external_ids': {'isrc': 'CA5KR2419698'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/17Nc99PG4IF49K5H8uNEQi'},
#    'href': 'https://api.spotify.com/v1/tracks/17Nc99PG4IF49K5H8uNEQi',
#    'id': '17Nc99PG4IF49K5H8uNEQi',
#    'name': 'BYE BYE!',
#    'popularity': 57,
#    'uri': 'spotify:track:17Nc99PG4IF49K5H8uNEQi',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-02-24T05:40:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/2EuOCirl08WxbRY2cfj4H5',
#     'id': '2EuOCirl08WxbRY2cfj4H5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739bf5280998453fee06ab1c6a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029bf5280998453fee06ab1c6a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519bf5280998453fee06ab1c6a',
#       'width': 64}],
#     'name': 'Life in Rio',
#     'release_date': '2023-03-17',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:2EuOCirl08WxbRY2cfj4H5',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65FHTCI8EmW94W0TdWb8ja'},
#       'href': 'https://api.spotify.com/v1/artists/65FHTCI8EmW94W0TdWb8ja',
#       'id': '65FHTCI8EmW94W0TdWb8ja',
#       'name': 'Slowboy',
#       'type': 'artist',
#       'uri': 'spotify:artist:65FHTCI8EmW94W0TdWb8ja'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1nccv1GNVkBdvsYi2FB5FB'},
#       'href': 'https://api.spotify.com/v1/artists/1nccv1GNVkBdvsYi2FB5FB',
#       'id': '1nccv1GNVkBdvsYi2FB5FB',
#       'name': 'NUEKI',
#       'type': 'artist',
#       'uri': 'spotify:artist:1nccv1GNVkBdvsYi2FB5FB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6QwlKB1hO357wh5oNuuInl'},
#       'href': 'https://api.spotify.com/v1/artists/6QwlKB1hO357wh5oNuuInl',
#       'id': '6QwlKB1hO357wh5oNuuInl',
#       'name': 'Crazy Mano',
#       'type': 'artist',
#       'uri': 'spotify:artist:6QwlKB1hO357wh5oNuuInl'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2EuOCirl08WxbRY2cfj4H5'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/65FHTCI8EmW94W0TdWb8ja'},
#      'href': 'https://api.spotify.com/v1/artists/65FHTCI8EmW94W0TdWb8ja',
#      'id': '65FHTCI8EmW94W0TdWb8ja',
#      'name': 'Slowboy',
#      'type': 'artist',
#      'uri': 'spotify:artist:65FHTCI8EmW94W0TdWb8ja'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1nccv1GNVkBdvsYi2FB5FB'},
#      'href': 'https://api.spotify.com/v1/artists/1nccv1GNVkBdvsYi2FB5FB',
#      'id': '1nccv1GNVkBdvsYi2FB5FB',
#      'name': 'NUEKI',
#      'type': 'artist',
#      'uri': 'spotify:artist:1nccv1GNVkBdvsYi2FB5FB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6QwlKB1hO357wh5oNuuInl'},
#      'href': 'https://api.spotify.com/v1/artists/6QwlKB1hO357wh5oNuuInl',
#      'id': '6QwlKB1hO357wh5oNuuInl',
#      'name': 'Crazy Mano',
#      'type': 'artist',
#      'uri': 'spotify:artist:6QwlKB1hO357wh5oNuuInl'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/23P2mSsBpPkfR9fTrOc1a4'},
#      'href': 'https://api.spotify.com/v1/artists/23P2mSsBpPkfR9fTrOc1a4',
#      'id': '23P2mSsBpPkfR9fTrOc1a4',
#      'name': 'TOLCHONOV',
#      'type': 'artist',
#      'uri': 'spotify:artist:23P2mSsBpPkfR9fTrOc1a4'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 94418,
#    'external_ids': {'isrc': 'QM4TX2337349'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7vtGOauV0Zz8Px5EJYm7d7'},
#    'href': 'https://api.spotify.com/v1/tracks/7vtGOauV0Zz8Px5EJYm7d7',
#    'id': '7vtGOauV0Zz8Px5EJYm7d7',
#    'name': 'Life in Rio',
#    'popularity': 70,
#    'uri': 'spotify:track:7vtGOauV0Zz8Px5EJYm7d7',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-02-24T05:42:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/1mAU33mqJDs4eekzZAQZvf',
#     'id': '1mAU33mqJDs4eekzZAQZvf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bd4f1d1c9e4888374d7faf63',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bd4f1d1c9e4888374d7faf63',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bd4f1d1c9e4888374d7faf63',
#       'width': 64}],
#     'name': 'Kerosene (Slowed)',
#     'release_date': '2022-12-10',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:1mAU33mqJDs4eekzZAQZvf',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5L9XA5GDsOOKNZfeOO8lmo'},
#       'href': 'https://api.spotify.com/v1/artists/5L9XA5GDsOOKNZfeOO8lmo',
#       'id': '5L9XA5GDsOOKNZfeOO8lmo',
#       'name': 'fam0uz',
#       'type': 'artist',
#       'uri': 'spotify:artist:5L9XA5GDsOOKNZfeOO8lmo'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1mAU33mqJDs4eekzZAQZvf'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5L9XA5GDsOOKNZfeOO8lmo'},
#      'href': 'https://api.spotify.com/v1/artists/5L9XA5GDsOOKNZfeOO8lmo',
#      'id': '5L9XA5GDsOOKNZfeOO8lmo',
#      'name': 'fam0uz',
#      'type': 'artist',
#      'uri': 'spotify:artist:5L9XA5GDsOOKNZfeOO8lmo'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 142105,
#    'external_ids': {'isrc': 'GX8LD2252629'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2weO22kObPnyX1jKQStb40'},
#    'href': 'https://api.spotify.com/v1/tracks/2weO22kObPnyX1jKQStb40',
#    'id': '2weO22kObPnyX1jKQStb40',
#    'name': 'Kerosene - Slowed',
#    'popularity': 68,
#    'uri': 'spotify:track:2weO22kObPnyX1jKQStb40',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-02-24T05:46:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/5rDznSixlUXNxJySfWQNb7',
#     'id': '5rDznSixlUXNxJySfWQNb7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bf696ff4fe2ac67d550b06a7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bf696ff4fe2ac67d550b06a7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bf696ff4fe2ac67d550b06a7',
#       'width': 64}],
#     'name': 'REI DO BRASIL',
#     'release_date': '2023-06-02',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5rDznSixlUXNxJySfWQNb7',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qycxIGAHj1KyoAQ6PGCO6'},
#       'href': 'https://api.spotify.com/v1/artists/3qycxIGAHj1KyoAQ6PGCO6',
#       'id': '3qycxIGAHj1KyoAQ6PGCO6',
#       'name': 'Seek',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qycxIGAHj1KyoAQ6PGCO6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5rDznSixlUXNxJySfWQNb7'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qycxIGAHj1KyoAQ6PGCO6'},
#      'href': 'https://api.spotify.com/v1/artists/3qycxIGAHj1KyoAQ6PGCO6',
#      'id': '3qycxIGAHj1KyoAQ6PGCO6',
#      'name': 'Seek',
#      'type': 'artist',
#      'uri': 'spotify:artist:3qycxIGAHj1KyoAQ6PGCO6'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 97846,
#    'external_ids': {'isrc': 'QM6P42377064'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Seth37t5I69wFbuGFrsiG'},
#    'href': 'https://api.spotify.com/v1/tracks/6Seth37t5I69wFbuGFrsiG',
#    'id': '6Seth37t5I69wFbuGFrsiG',
#    'name': 'REI DO BRASIL',
#    'popularity': 66,
#    'uri': 'spotify:track:6Seth37t5I69wFbuGFrsiG',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-02-24T05:48:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/7pv0piZjVlLEIYUXEQKX6x',
#     'id': '7pv0piZjVlLEIYUXEQKX6x',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731cc26b99228609a1b284c10e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021cc26b99228609a1b284c10e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511cc26b99228609a1b284c10e',
#       'width': 64}],
#     'name': 'NO GOING BACK',
#     'release_date': '2023-10-18',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:7pv0piZjVlLEIYUXEQKX6x',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nl0CCx6PpEOOr2Z2ThPdp'},
#       'href': 'https://api.spotify.com/v1/artists/4nl0CCx6PpEOOr2Z2ThPdp',
#       'id': '4nl0CCx6PpEOOr2Z2ThPdp',
#       'name': 'xxanteria',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nl0CCx6PpEOOr2Z2ThPdp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7pv0piZjVlLEIYUXEQKX6x'},
#     'total_tracks': 8},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4nl0CCx6PpEOOr2Z2ThPdp'},
#      'href': 'https://api.spotify.com/v1/artists/4nl0CCx6PpEOOr2Z2ThPdp',
#      'id': '4nl0CCx6PpEOOr2Z2ThPdp',
#      'name': 'xxanteria',
#      'type': 'artist',
#      'uri': 'spotify:artist:4nl0CCx6PpEOOr2Z2ThPdp'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 104013,
#    'external_ids': {'isrc': 'QZS7J2358214'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0rb7HcBkdMPp04ybHBfX41'},
#    'href': 'https://api.spotify.com/v1/tracks/0rb7HcBkdMPp04ybHBfX41',
#    'id': '0rb7HcBkdMPp04ybHBfX41',
#    'name': 'BAIXO',
#    'popularity': 69,
#    'uri': 'spotify:track:0rb7HcBkdMPp04ybHBfX41',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-02-24T06:31:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/5a9uibuVUtMag0L3Fo8gkQ',
#     'id': '5a9uibuVUtMag0L3Fo8gkQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27323156126d61feb32551349f5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0223156126d61feb32551349f5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485123156126d61feb32551349f5',
#       'width': 64}],
#     'name': 'Untitled #13 (Super Slowed)',
#     'release_date': '2023-08-09',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5a9uibuVUtMag0L3Fo8gkQ',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xNuIo74R6m1eXaz7RlpZ6'},
#       'href': 'https://api.spotify.com/v1/artists/4xNuIo74R6m1eXaz7RlpZ6',
#       'id': '4xNuIo74R6m1eXaz7RlpZ6',
#       'name': 'glwzbll',
#       'type': 'artist',
#       'uri': 'spotify:artist:4xNuIo74R6m1eXaz7RlpZ6'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5a9uibuVUtMag0L3Fo8gkQ'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4xNuIo74R6m1eXaz7RlpZ6'},
#      'href': 'https://api.spotify.com/v1/artists/4xNuIo74R6m1eXaz7RlpZ6',
#      'id': '4xNuIo74R6m1eXaz7RlpZ6',
#      'name': 'glwzbll',
#      'type': 'artist',
#      'uri': 'spotify:artist:4xNuIo74R6m1eXaz7RlpZ6'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 192000,
#    'external_ids': {'isrc': 'RUA1D2386100'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3fC7BKJN66Tyq44x6Try2R'},
#    'href': 'https://api.spotify.com/v1/tracks/3fC7BKJN66Tyq44x6Try2R',
#    'id': '3fC7BKJN66Tyq44x6Try2R',
#    'name': 'Untitled #13 (Super Slowed)',
#    'popularity': 67,
#    'uri': 'spotify:track:3fC7BKJN66Tyq44x6Try2R',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-03-21T12:23:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
# ...
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/51F5iHYpECc8dd9Wjqv15o',
#     'id': '51F5iHYpECc8dd9Wjqv15o',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ecf02d417f93c338e54f77b4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ecf02d417f93c338e54f77b4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ecf02d417f93c338e54f77b4',
#       'width': 64}],
#     'name': 'Eu Sento Gabu!',
#     'release_date': '2024-04-19',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:51F5iHYpECc8dd9Wjqv15o',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6OwbqUSj4XbZdjexPsKkdH'},
#       'href': 'https://api.spotify.com/v1/artists/6OwbqUSj4XbZdjexPsKkdH',
#       'id': '6OwbqUSj4XbZdjexPsKkdH',
#       'name': 'PXLWYSE',
#       'type': 'artist',
#       'uri': 'spotify:artist:6OwbqUSj4XbZdjexPsKkdH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/51F5iHYpECc8dd9Wjqv15o'},
#     'total_tracks': 4},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6OwbqUSj4XbZdjexPsKkdH'},
#      'href': 'https://api.spotify.com/v1/artists/6OwbqUSj4XbZdjexPsKkdH',
#      'id': '6OwbqUSj4XbZdjexPsKkdH',
#      'name': 'PXLWYSE',
#      'type': 'artist',
#      'uri': 'spotify:artist:6OwbqUSj4XbZdjexPsKkdH'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 83754,
#    'external_ids': {'isrc': 'FRX282495842'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/24WBge8e53iDTeXOtVB02s'},
#    'href': 'https://api.spotify.com/v1/tracks/24WBge8e53iDTeXOtVB02s',
#    'id': '24WBge8e53iDTeXOtVB02s',
#    'name': 'Eu Sento Gabu!',
#    'popularity': 76,
#    'uri': 'spotify:track:24WBge8e53iDTeXOtVB02s',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-12-07T06:59:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/06a7H7nusNMvM7yL8m3fy1',
#     'id': '06a7H7nusNMvM7yL8m3fy1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bb7e0eb64fae8dbd5b9d2a12',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bb7e0eb64fae8dbd5b9d2a12',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bb7e0eb64fae8dbd5b9d2a12',
#       'width': 64}],
#     'name': 'AURA',
#     'release_date': '2024-07-12',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:06a7H7nusNMvM7yL8m3fy1',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Sdc6ySbIvzO0X9vbyHzWm'},
#       'href': 'https://api.spotify.com/v1/artists/1Sdc6ySbIvzO0X9vbyHzWm',
#       'id': '1Sdc6ySbIvzO0X9vbyHzWm',
#       'name': 'Ogryzek',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Sdc6ySbIvzO0X9vbyHzWm'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/06a7H7nusNMvM7yL8m3fy1'},
#     'total_tracks': 3},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Sdc6ySbIvzO0X9vbyHzWm'},
#      'href': 'https://api.spotify.com/v1/artists/1Sdc6ySbIvzO0X9vbyHzWm',
#      'id': '1Sdc6ySbIvzO0X9vbyHzWm',
#      'name': 'Ogryzek',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Sdc6ySbIvzO0X9vbyHzWm'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 137986,
#    'external_ids': {'isrc': 'USUYG1561712'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3bQ6ECgoGPgT6cvjOmMPAG'},
#    'href': 'https://api.spotify.com/v1/tracks/3bQ6ECgoGPgT6cvjOmMPAG',
#    'id': '3bQ6ECgoGPgT6cvjOmMPAG',
#    'name': 'AURA - Slowed',
#    'popularity': 70,
#    'uri': 'spotify:track:3bQ6ECgoGPgT6cvjOmMPAG',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2024-12-07T07:05:28Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/1qlnjo9SZtK01FqDyjv6nM',
#     'id': '1qlnjo9SZtK01FqDyjv6nM',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730baac8321fa3ae0f5a4ca424',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020baac8321fa3ae0f5a4ca424',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510baac8321fa3ae0f5a4ca424',
#       'width': 64}],
#     'name': 'EI DO SENSACIO!',
#     'release_date': '2024-07-29',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:1qlnjo9SZtK01FqDyjv6nM',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0oGN0s7dqyWbR41yMsNs0R'},
#       'href': 'https://api.spotify.com/v1/artists/0oGN0s7dqyWbR41yMsNs0R',
#       'id': '0oGN0s7dqyWbR41yMsNs0R',
#       'name': 'princce',
#       'type': 'artist',
#       'uri': 'spotify:artist:0oGN0s7dqyWbR41yMsNs0R'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1qlnjo9SZtK01FqDyjv6nM'},
#     'total_tracks': 4},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0oGN0s7dqyWbR41yMsNs0R'},
#      'href': 'https://api.spotify.com/v1/artists/0oGN0s7dqyWbR41yMsNs0R',
#      'id': '0oGN0s7dqyWbR41yMsNs0R',
#      'name': 'princce',
#      'type': 'artist',
#      'uri': 'spotify:artist:0oGN0s7dqyWbR41yMsNs0R'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 101089,
#    'external_ids': {'isrc': 'UKZGC2406941'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2vbl2mqgwZCPqiYjn3MPhS'},
#    'href': 'https://api.spotify.com/v1/tracks/2vbl2mqgwZCPqiYjn3MPhS',
#    'id': '2vbl2mqgwZCPqiYjn3MPhS',
#    'name': 'EI DO SENSACIO!',
#    'popularity': 65,
#    'uri': 'spotify:track:2vbl2mqgwZCPqiYjn3MPhS',
#    'is_local': False},
#   'video_thumbnail': {'url': None}}]

# %%
data['items'][0]['track']['album']['id']
# Out:
# '6DptPhwLku8xvWBodULnC6'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Orquestra Maldita'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-06-15'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/6DptPhwLku8xvWBodULnC6'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '6DptPhwLku8xvWBodULnC6',
#   'name': 'Orquestra Maldita',
#   'release_date': '2023-06-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6DptPhwLku8xvWBodULnC6'},
#  {'album_id': '0ZE5fMneYtdl93X1GHqxSH',
#   'name': 'BYE BYE!',
#   'release_date': '2024-01-12',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/0ZE5fMneYtdl93X1GHqxSH'},
#  {'album_id': '2EuOCirl08WxbRY2cfj4H5',
#   'name': 'Life in Rio',
#   'release_date': '2023-03-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2EuOCirl08WxbRY2cfj4H5'},
#  {'album_id': '1mAU33mqJDs4eekzZAQZvf',
#   'name': 'Kerosene (Slowed)',
#   'release_date': '2022-12-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1mAU33mqJDs4eekzZAQZvf'},
#  {'album_id': '5rDznSixlUXNxJySfWQNb7',
#   'name': 'REI DO BRASIL',
#   'release_date': '2023-06-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5rDznSixlUXNxJySfWQNb7'},
#  {'album_id': '7pv0piZjVlLEIYUXEQKX6x',
#   'name': 'NO GOING BACK',
#   'release_date': '2023-10-18',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/7pv0piZjVlLEIYUXEQKX6x'},
#  {'album_id': '5a9uibuVUtMag0L3Fo8gkQ',
#   'name': 'Untitled #13 (Super Slowed)',
#   'release_date': '2023-08-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5a9uibuVUtMag0L3Fo8gkQ'},
#  {'album_id': '4FRxgE6LA2UGJ5yz8diaI9',
#   'name': 'FUNKED UP',
#   'release_date': '2024-01-19',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/4FRxgE6LA2UGJ5yz8diaI9'},
#  {'album_id': '4cfBuRZw1az5lIdTYxuOPq',
#   'name': 'BIBI PHONK BR',
#   'release_date': '2023-08-25',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4cfBuRZw1az5lIdTYxuOPq'},
#  {'album_id': '1xF2L9FhsEG6CPf9ERW7vH',
#   'name': 'TREINAMENTO DE FORÇA',
#   'release_date': '2023-07-21',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1xF2L9FhsEG6CPf9ERW7vH'},
#  {'album_id': '4QVkiRbkPGu3KETjFzmf99',
#   'name': 'SMOKE IT OFF!',
#   'release_date': '2023-07-31',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/4QVkiRbkPGu3KETjFzmf99'},
#  {'album_id': '3xCc8FxQsm6AE7ZWJ7h5sx',
#   'name': 'SLAY!',
#   'release_date': '2024-03-15',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/3xCc8FxQsm6AE7ZWJ7h5sx'},
#  {'album_id': '5J00ADHG1jlJiLjQDPURVh',
#   'name': 'ICEWHORE!',
#   'release_date': '2023-03-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5J00ADHG1jlJiLjQDPURVh'},
#  {'album_id': '7jGx3EgvTllCvIhKIJuXce',
#   'name': 'FUNK ESTRANHO - SUPER SLOWED',
#   'release_date': '2024-04-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7jGx3EgvTllCvIhKIJuXce'},
#  {'album_id': '4Qmw0mV9qMba2FQVUh0BYz',
#   'name': 'Louca Encubada',
#   'release_date': '2023-10-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4Qmw0mV9qMba2FQVUh0BYz'},
#  {'album_id': '7EWDvEG6vKIjTBk3rGMtP0',
#   'name': 'BRODYAGA FUNK',
#   'release_date': '2023-11-17',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/7EWDvEG6vKIjTBk3rGMtP0'},
#  {'album_id': '3joHEvqURxvBwrT5JZS3Sn',
#   'name': '✻H+3+ЯД✻7luCJIo0T6...',
#   'release_date': '2024-02-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3joHEvqURxvBwrT5JZS3Sn'},
#  {'album_id': '48LBNjlJar3GGB3xqp4H7E',
#   'name': 'THE TUTUTUTU',
#   'release_date': '2023-02-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/48LBNjlJar3GGB3xqp4H7E'},
#  {'album_id': '5T9u88WBOgCsGk3GT30Z3r',
#   'name': 'Bero 02',
#   'release_date': '2023-10-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5T9u88WBOgCsGk3GT30Z3r'},
#  {'album_id': '6k1LVdbZDF0cReCgg8ZSCt',
#   'name': 'Me Papa Que É Pop (Super Slowed)',
#   'release_date': '2024-04-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6k1LVdbZDF0cReCgg8ZSCt'},
#  {'album_id': '5mGMCvuF70Alfy0FXg3Sn7',
#   'name': 'x-tudo',
#   'release_date': '2024-01-25',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5mGMCvuF70Alfy0FXg3Sn7'},
#  {'album_id': '0t5DOdL4qdnzDeE6ctJwGO',
#   'name': 'THOMAS (Remixes)',
#   'release_date': '2024-04-16',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/0t5DOdL4qdnzDeE6ctJwGO'},
#  {'album_id': '58Uel2jPuFAf4bRiWHLYVz',
#   'name': 'MONTAGEM VOZES PROFUNDAS (TikTok Version)',
#   'release_date': '2024-07-12',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/58Uel2jPuFAf4bRiWHLYVz'},
#  {'album_id': '41y6rWxN7w06zrmxyA3Jk4',
#   'name': 'Slide da Treme Melódica v2 (Remixes)',
#   'release_date': '2024-05-17',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/41y6rWxN7w06zrmxyA3Jk4'},
#  {'album_id': '1QFKbF3Oot9Ad1NnRCAG32',
#   'name': 'X-SLIDE',
#   'release_date': '2024-05-10',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1QFKbF3Oot9Ad1NnRCAG32'},
#  {'album_id': '4z0nL9bblVphvhmt8o15yO',
#   'name': 'METAMORPHOSIS (Slowed + Reverb)',
#   'release_date': '2022-06-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4z0nL9bblVphvhmt8o15yO'},
#  {'album_id': '5rl2NDQDv9VpZLoEFOaYNg',
#   'name': 'MONTAGEM INVASÃO',
#   'release_date': '2024-03-21',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5rl2NDQDv9VpZLoEFOaYNg'},
#  {'album_id': '1k9oQsBjwIhc4vF32zxvY5',
#   'name': 'NEXT!',
#   'release_date': '2024-06-07',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1k9oQsBjwIhc4vF32zxvY5'},
#  {'album_id': '4ibsk1iPM7xDpJkNXREmsl',
#   'name': 'MANDA BALA',
#   'release_date': '2023-12-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4ibsk1iPM7xDpJkNXREmsl'},
#  {'album_id': '6jQlknQwPszOU2pYBkNmO5',
#   'name': 'AUTOMOTIVO PA PA PAPAI',
#   'release_date': '2024-04-29',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6jQlknQwPszOU2pYBkNmO5'},
#  {'album_id': '1ILssfrknV8cQv5QvwBGUY',
#   'name': 'DNA',
#   'release_date': '2023-12-21',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/1ILssfrknV8cQv5QvwBGUY'},
#  {'album_id': '0cpfgDzjHZuYfiBc7jPsn6',
#   'name': 'Funk of Galáctico',
#   'release_date': '2024-04-05',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/0cpfgDzjHZuYfiBc7jPsn6'},
#  {'album_id': '0TwAp1jAUFp1PQtdDlDDW3',
#   'name': 'GHOST!',
#   'release_date': '2022-12-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0TwAp1jAUFp1PQtdDlDDW3'},
#  {'album_id': '3Rq3xeWRYKYWX8GKXZZ3PW',
#   'name': 'MTG - VINGANÇA (Slowed + Reverb)',
#   'release_date': '2024-01-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3Rq3xeWRYKYWX8GKXZZ3PW'},
#  {'album_id': '6XPDmXgFC3kcfiuwNKmv0e',
#   'name': 'Cuando Se Te Moja La Tarea (Remixes)',
#   'release_date': '2024-05-08',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/6XPDmXgFC3kcfiuwNKmv0e'},
#  {'album_id': '3tSeUNn7yOQPEex7jwS9Bf',
#   'name': 'GLORY',
#   'release_date': '2024-05-24',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3tSeUNn7yOQPEex7jwS9Bf'},
#  {'album_id': '1Wr2LyF0JSHHPv9nGXgFTN',
#   'name': 'O Melhor no Que Faz 3.0 [Slowed]',
#   'release_date': '2024-07-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1Wr2LyF0JSHHPv9nGXgFTN'},
#  {'album_id': '4Fpr7mZ709qg0Iu1ESYNwz',
#   'name': 'SEQUÊNCIA MALÉFICA 1.0',
#   'release_date': '2024-02-19',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/4Fpr7mZ709qg0Iu1ESYNwz'},
#  {'album_id': '56DdzvipiCE36a7wU5vyAt',
#   'name': 'SONIC.EXE (ULTRA SLOWED)',
#   'release_date': '2024-01-29',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/56DdzvipiCE36a7wU5vyAt'},
#  {'album_id': '6S7WfaIcSWxr1m2nNEPkcF',
#   'name': 'TREN ENJOYER',
#   'release_date': '2023-12-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6S7WfaIcSWxr1m2nNEPkcF'},
#  {'album_id': '7cNqBJdXx8dgoXegihUPVN',
#   'name': 'Turu R9',
#   'release_date': '2024-04-01',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/7cNqBJdXx8dgoXegihUPVN'},
#  {'album_id': '5eEfzNcFaXPsBXJzkPiD3S',
#   'name': 'Beeper Funk (Slowed)',
#   'release_date': '2024-08-09',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/5eEfzNcFaXPsBXJzkPiD3S'},
#  {'album_id': '73WPr90gWBdNLg1KHkgpc0',
#   'name': 'PROTECTION CHARM (SLOW & HARD VERSION)',
#   'release_date': '2023-10-03',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/73WPr90gWBdNLg1KHkgpc0'},
#  {'album_id': '6Zd0Hg3HKVH7xhBPgESQy1',
#   'name': 'FUNK DO BOUNCE (Slowed)',
#   'release_date': '2024-08-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6Zd0Hg3HKVH7xhBPgESQy1'},
#  {'album_id': '7wMbhXcy5aBZhpv6HYTIlx',
#   'name': 'void',
#   'release_date': '2024-08-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/7wMbhXcy5aBZhpv6HYTIlx'},
#  {'album_id': '6dNugoBYWvUDQDtLurImhw',
#   'name': 'X-TALI',
#   'release_date': '2024-08-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6dNugoBYWvUDQDtLurImhw'},
#  {'album_id': '3Ar02fcnzPDg1xvy05pWff',
#   'name': 'Se Paciente Funk',
#   'release_date': '2024-07-26',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3Ar02fcnzPDg1xvy05pWff'},
#  {'album_id': '09xRsRc7pX399wCGElOfMT',
#   'name': 'BRUXO FANTASMA',
#   'release_date': '2024-08-16',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/09xRsRc7pX399wCGElOfMT'},
#  {'album_id': '1Idktx9vdSSkm1yxABycnf',
#   'name': 'DON`T STOP',
#   'release_date': '2024-04-19',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/1Idktx9vdSSkm1yxABycnf'},
#  {'album_id': '03GXBC2T6YdaBZo754wYlH',
#   'name': 'Montagem Sonic Ritmado 1.0 (Super Slowed)',
#   'release_date': '2024-05-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/03GXBC2T6YdaBZo754wYlH'},
#  {'album_id': '5NJDkJdeVRTLpOJalNfb95',
#   'name': 'Montagem Bionica Espectral 2',
#   'release_date': '2024-07-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5NJDkJdeVRTLpOJalNfb95'},
#  {'album_id': '1kmsUHDC0n611meNgzRkuw',
#   'name': 'FUNK UNIVERSO',
#   'release_date': '2024-07-03',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1kmsUHDC0n611meNgzRkuw'},
#  {'album_id': '51F5iHYpECc8dd9Wjqv15o',
#   'name': 'Eu Sento Gabu!',
#   'release_date': '2024-04-19',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/51F5iHYpECc8dd9Wjqv15o'},
#  {'album_id': '06a7H7nusNMvM7yL8m3fy1',
#   'name': 'AURA',
#   'release_date': '2024-07-12',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/06a7H7nusNMvM7yL8m3fy1'},
#  {'album_id': '1qlnjo9SZtK01FqDyjv6nM',
#   'name': 'EI DO SENSACIO!',
#   'release_date': '2024-07-29',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/1qlnjo9SZtK01FqDyjv6nM'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2024-02-23T14:40:21Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#   'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#   'type': 'user',
#   'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': True,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/6DptPhwLku8xvWBodULnC6',
#    'id': '6DptPhwLku8xvWBodULnC6',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c658105590edfb75e0714a90',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c658105590edfb75e0714a90',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c658105590edfb75e0714a90',
#      'width': 64}],
#    'name': 'Orquestra Maldita',
#    'release_date': '2023-06-15',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:6DptPhwLku8xvWBodULnC6',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rt96VXGtEgD4uSOJ6B69H'},
#      'href': 'https://api.spotify.com/v1/artists/3rt96VXGtEgD4uSOJ6B69H',
#      'id': '3rt96VXGtEgD4uSOJ6B69H',
#      'name': 'TRASHXRL',
#      'type': 'artist',
#      'uri': 'spotify:artist:3rt96VXGtEgD4uSOJ6B69H'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3l4fsEzoeabsET7ddv0lZW'},
#      'href': 'https://api.spotify.com/v1/artists/3l4fsEzoeabsET7ddv0lZW',
#      'id': '3l4fsEzoeabsET7ddv0lZW',
#      'name': 'Mc Delux',
#      'type': 'artist',
#      'uri': 'spotify:artist:3l4fsEzoeabsET7ddv0lZW'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6DptPhwLku8xvWBodULnC6'},
#    'total_tracks': 1},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rt96VXGtEgD4uSOJ6B69H'},
#     'href': 'https://api.spotify.com/v1/artists/3rt96VXGtEgD4uSOJ6B69H',
#     'id': '3rt96VXGtEgD4uSOJ6B69H',
#     'name': 'TRASHXRL',
#     'type': 'artist',
#     'uri': 'spotify:artist:3rt96VXGtEgD4uSOJ6B69H'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3l4fsEzoeabsET7ddv0lZW'},
#     'href': 'https://api.spotify.com/v1/artists/3l4fsEzoeabsET7ddv0lZW',
#     'id': '3l4fsEzoeabsET7ddv0lZW',
#     'name': 'Mc Delux',
#     'type': 'artist',
#     'uri': 'spotify:artist:3l4fsEzoeabsET7ddv0lZW'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 119777,
#   'external_ids': {'isrc': 'BX7272300515'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7hcagAQDiI0TgUOv337NIr'},
#   'href': 'https://api.spotify.com/v1/tracks/7hcagAQDiI0TgUOv337NIr',
#   'id': '7hcagAQDiI0TgUOv337NIr',
#   'name': 'Orquestra Maldita',
#   'popularity': 72,
#   'uri': 'spotify:track:7hcagAQDiI0TgUOv337NIr',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '3rt96VXGtEgD4uSOJ6B69H',
#   'artist_name': 'TRASHXRL',
#   'external_url': 'https://api.spotify.com/v1/artists/3rt96VXGtEgD4uSOJ6B69H'},
#  {'artist_id': '3l4fsEzoeabsET7ddv0lZW',
#   'artist_name': 'Mc Delux',
#   'external_url': 'https://api.spotify.com/v1/artists/3l4fsEzoeabsET7ddv0lZW'},
#  {'artist_id': '5sj3P8OH8O5aVmey1C2mf4',
#   'artist_name': 'PXRKX',
#   'external_url': 'https://api.spotify.com/v1/artists/5sj3P8OH8O5aVmey1C2mf4'},
#  {'artist_id': '5hfVobwxTC73whNVhzwlcP',
#   'artist_name': 'RZXT!',
#   'external_url': 'https://api.spotify.com/v1/artists/5hfVobwxTC73whNVhzwlcP'},
#  {'artist_id': '65FHTCI8EmW94W0TdWb8ja',
#   'artist_name': 'Slowboy',
#   'external_url': 'https://api.spotify.com/v1/artists/65FHTCI8EmW94W0TdWb8ja'},
#  {'artist_id': '1nccv1GNVkBdvsYi2FB5FB',
#   'artist_name': 'NUEKI',
#   'external_url': 'https://api.spotify.com/v1/artists/1nccv1GNVkBdvsYi2FB5FB'},
#  {'artist_id': '6QwlKB1hO357wh5oNuuInl',
#   'artist_name': 'Crazy Mano',
#   'external_url': 'https://api.spotify.com/v1/artists/6QwlKB1hO357wh5oNuuInl'},
#  {'artist_id': '23P2mSsBpPkfR9fTrOc1a4',
#   'artist_name': 'TOLCHONOV',
#   'external_url': 'https://api.spotify.com/v1/artists/23P2mSsBpPkfR9fTrOc1a4'},
#  {'artist_id': '5L9XA5GDsOOKNZfeOO8lmo',
#   'artist_name': 'fam0uz',
#   'external_url': 'https://api.spotify.com/v1/artists/5L9XA5GDsOOKNZfeOO8lmo'},
#  {'artist_id': '3qycxIGAHj1KyoAQ6PGCO6',
#   'artist_name': 'Seek',
#   'external_url': 'https://api.spotify.com/v1/artists/3qycxIGAHj1KyoAQ6PGCO6'},
#  {'artist_id': '4nl0CCx6PpEOOr2Z2ThPdp',
#   'artist_name': 'xxanteria',
#   'external_url': 'https://api.spotify.com/v1/artists/4nl0CCx6PpEOOr2Z2ThPdp'},
#  {'artist_id': '4xNuIo74R6m1eXaz7RlpZ6',
#   'artist_name': 'glwzbll',
#   'external_url': 'https://api.spotify.com/v1/artists/4xNuIo74R6m1eXaz7RlpZ6'},
#  {'artist_id': '4nl0CCx6PpEOOr2Z2ThPdp',
#   'artist_name': 'xxanteria',
#   'external_url': 'https://api.spotify.com/v1/artists/4nl0CCx6PpEOOr2Z2ThPdp'},
#  {'artist_id': '6JjQbtAO09K7qBEW2pdX5s',
#   'artist_name': 'isq',
#   'external_url': 'https://api.spotify.com/v1/artists/6JjQbtAO09K7qBEW2pdX5s'},
#  {'artist_id': '6R26kGib2ubbZJMh7kKVGV',
#   'artist_name': 'Bibi Babydoll',
#   'external_url': 'https://api.spotify.com/v1/artists/6R26kGib2ubbZJMh7kKVGV'},
#  {'artist_id': '3QMpCp3GHiHXgnX1LldXWe',
#   'artist_name': 'DJ FKU',
#   'external_url': 'https://api.spotify.com/v1/artists/3QMpCp3GHiHXgnX1LldXWe'},
#  {'artist_id': '31VaidRoI1NnHfyY8SxSL7',
#   'artist_name': 'TRXVELER',
#   'external_url': 'https://api.spotify.com/v1/artists/31VaidRoI1NnHfyY8SxSL7'},
#  {'artist_id': '1TTHC3GlNDaE5eVoC3BVxm',
#   'artist_name': 'Lumi Athena',
#   'external_url': 'https://api.spotify.com/v1/artists/1TTHC3GlNDaE5eVoC3BVxm'},
#  {'artist_id': '0H942IkjXv9bjx5OxoG7kh',
#   'artist_name': 'jnhygs',
#   'external_url': 'https://api.spotify.com/v1/artists/0H942IkjXv9bjx5OxoG7kh'},
#  {'artist_id': '3Xd2WSaNywx5gn1pgRPFjF',
#   'artist_name': 'Eternxlkz',
#   'external_url': 'https://api.spotify.com/v1/artists/3Xd2WSaNywx5gn1pgRPFjF'},
#  {'artist_id': '1TTHC3GlNDaE5eVoC3BVxm',
#   'artist_name': 'Lumi Athena',
#   'external_url': 'https://api.spotify.com/v1/artists/1TTHC3GlNDaE5eVoC3BVxm'},
#  {'artist_id': '4SbtvEgtu7QsmFjjBzyV8F',
#   'artist_name': 'ALXIKE',
#   'external_url': 'https://api.spotify.com/v1/artists/4SbtvEgtu7QsmFjjBzyV8F'},
#  {'artist_id': '6U0dJxYVB41L8WDZ02Nwuk',
#   'artist_name': 'Dj Samir',
#   'external_url': 'https://api.spotify.com/v1/artists/6U0dJxYVB41L8WDZ02Nwuk'},
#  {'artist_id': '0ngIeXf9eyYCjC1Nen0ux8',
#   'artist_name': 'Rodricci',
#   'external_url': 'https://api.spotify.com/v1/artists/0ngIeXf9eyYCjC1Nen0ux8'},
#  {'artist_id': '3TgsOVvQlRt3sBrIhQ7U9k',
#   'artist_name': 'Launch13',
#   'external_url': 'https://api.spotify.com/v1/artists/3TgsOVvQlRt3sBrIhQ7U9k'},
#  {'artist_id': '3Xd2WSaNywx5gn1pgRPFjF',
#   'artist_name': 'Eternxlkz',
#   'external_url': 'https://api.spotify.com/v1/artists/3Xd2WSaNywx5gn1pgRPFjF'},
#  {'artist_id': '4hJrxZPQydibSnMMq7PpB9',
#   'artist_name': 'vyrval',
#   'external_url': 'https://api.spotify.com/v1/artists/4hJrxZPQydibSnMMq7PpB9'},
#  {'artist_id': '2GWsM5HZRVvUSKFgQczU7F',
#   'artist_name': 'Jaegershu',
#   'external_url': 'https://api.spotify.com/v1/artists/2GWsM5HZRVvUSKFgQczU7F'},
#  {'artist_id': '4C5EDmZfgkkSwUVFSvuUNP',
#   'artist_name': 'Anar',
#   'external_url': 'https://api.spotify.com/v1/artists/4C5EDmZfgkkSwUVFSvuUNP'},
#  {'artist_id': '4DWPOsGWbW7sBHb1UuBvWs',
#   'artist_name': 'Polaris',
#   'external_url': 'https://api.spotify.com/v1/artists/4DWPOsGWbW7sBHb1UuBvWs'},
#  {'artist_id': '6MSMZkBlZT4vhQmjO5Ynv3',
#   'artist_name': 'Dj Brunin XM',
#   'external_url': 'https://api.spotify.com/v1/artists/6MSMZkBlZT4vhQmjO5Ynv3'},
#  {'artist_id': '62NFUnRQI3ctTgZdCquSHD',
#   'artist_name': 'Mc Lullu',
#   'external_url': 'https://api.spotify.com/v1/artists/62NFUnRQI3ctTgZdCquSHD'},
#  {'artist_id': '1M02J1PLobtQYok93DEvVa',
#   'artist_name': 'slxughter',
#   'external_url': 'https://api.spotify.com/v1/artists/1M02J1PLobtQYok93DEvVa'},
#  {'artist_id': '0f1IECbrVV952unZkzrsg2',
#   'artist_name': 'Mc Gw',
#   'external_url': 'https://api.spotify.com/v1/artists/0f1IECbrVV952unZkzrsg2'},
#  {'artist_id': '33rnQWadiG2aauIwIxPxfB',
#   'artist_name': 'ZWE1HVNDXR',
#   'external_url': 'https://api.spotify.com/v1/artists/33rnQWadiG2aauIwIxPxfB'},
#  {'artist_id': '2APh66XEiqOiDt3bKhBWmn',
#   'artist_name': 'NONTHENSE',
#   'external_url': 'https://api.spotify.com/v1/artists/2APh66XEiqOiDt3bKhBWmn'},
#  {'artist_id': '3rX0drWPVa50yFG3HqzX0T',
#   'artist_name': 'DJ MAXZZ',
#   'external_url': 'https://api.spotify.com/v1/artists/3rX0drWPVa50yFG3HqzX0T'},
#  {'artist_id': '68J0b3Hj9aurxWUiy9FUMu',
#   'artist_name': 'DJ JL3 DA ZN',
#   'external_url': 'https://api.spotify.com/v1/artists/68J0b3Hj9aurxWUiy9FUMu'},
#  {'artist_id': '33wh7J44m0CrsAFj2LuRk2',
#   'artist_name': 'DJ CD 011',
#   'external_url': 'https://api.spotify.com/v1/artists/33wh7J44m0CrsAFj2LuRk2'},
#  {'artist_id': '7nM7RtPXQ6jwNlFTfPyZnA',
#   'artist_name': 'DJ FNK',
#   'external_url': 'https://api.spotify.com/v1/artists/7nM7RtPXQ6jwNlFTfPyZnA'},
#  {'artist_id': '4DWPOsGWbW7sBHb1UuBvWs',
#   'artist_name': 'Polaris',
#   'external_url': 'https://api.spotify.com/v1/artists/4DWPOsGWbW7sBHb1UuBvWs'},
#  {'artist_id': '2vPnS0IpayC2RVFuQA08R4',
#   'artist_name': '2KE',
#   'external_url': 'https://api.spotify.com/v1/artists/2vPnS0IpayC2RVFuQA08R4'},
#  {'artist_id': '4jM6R2LK78dVTqHVUoA4li',
#   'artist_name': '808iuli',
#   'external_url': 'https://api.spotify.com/v1/artists/4jM6R2LK78dVTqHVUoA4li'},
#  {'artist_id': '5hKGLu4Ik88FzWcTPhWNTN',
#   'artist_name': 'INTERWORLD',
#   'external_url': 'https://api.spotify.com/v1/artists/5hKGLu4Ik88FzWcTPhWNTN'},
#  {'artist_id': '3c4ngCW3y8USmyrjRdB1mG',
#   'artist_name': 'ARXMANE',
#   'external_url': 'https://api.spotify.com/v1/artists/3c4ngCW3y8USmyrjRdB1mG'},
#  {'artist_id': '6BWtcMF39LT5Db5FT54YYG',
#   'artist_name': 'NCTS',
#   'external_url': 'https://api.spotify.com/v1/artists/6BWtcMF39LT5Db5FT54YYG'},
#  {'artist_id': '09cKncAQn28NqTUORLMwSR',
#   'artist_name': 'Ariis',
#   'external_url': 'https://api.spotify.com/v1/artists/09cKncAQn28NqTUORLMwSR'},
#  {'artist_id': '0ayuHZiwRQ5jXBaGGSEjBv',
#   'artist_name': 'DJ RIO',
#   'external_url': 'https://api.spotify.com/v1/artists/0ayuHZiwRQ5jXBaGGSEjBv'},
#  {'artist_id': '5MQG067ASfGn0Cf1nE0S8g',
#   'artist_name': '0to8',
#   'external_url': 'https://api.spotify.com/v1/artists/5MQG067ASfGn0Cf1nE0S8g'},
#  {'artist_id': '5IpS1TN1Crp8Ym4zjiIrtK',
#   'artist_name': 'LXNGVX',
#   'external_url': 'https://api.spotify.com/v1/artists/5IpS1TN1Crp8Ym4zjiIrtK'},
#  {'artist_id': '6kLsCQ1gKvJmjmC8XbfqFE',
#   'artist_name': 'VISXGE',
#   'external_url': 'https://api.spotify.com/v1/artists/6kLsCQ1gKvJmjmC8XbfqFE'},
#  {'artist_id': '3eTy7yvRHnpPKY4hNCfYYX',
#   'artist_name': 'SXID',
#   'external_url': 'https://api.spotify.com/v1/artists/3eTy7yvRHnpPKY4hNCfYYX'},
#  {'artist_id': '6R26kGib2ubbZJMh7kKVGV',
#   'artist_name': 'Bibi Babydoll',
#   'external_url': 'https://api.spotify.com/v1/artists/6R26kGib2ubbZJMh7kKVGV'},
#  {'artist_id': '3YNdAmDzM5zMbGYeaSCe6A',
#   'artist_name': 'phonk.me',
#   'external_url': 'https://api.spotify.com/v1/artists/3YNdAmDzM5zMbGYeaSCe6A'},
#  {'artist_id': '3nLZDVpDU6RrQ9k98yHTKh',
#   'artist_name': 'KIIXSHI',
#   'external_url': 'https://api.spotify.com/v1/artists/3nLZDVpDU6RrQ9k98yHTKh'},
#  {'artist_id': '3QMpCp3GHiHXgnX1LldXWe',
#   'artist_name': 'DJ FKU',
#   'external_url': 'https://api.spotify.com/v1/artists/3QMpCp3GHiHXgnX1LldXWe'},
#  {'artist_id': '2DtIt7mMzdaEEFVUbSmnoU',
#   'artist_name': 'LDRR',
#   'external_url': 'https://api.spotify.com/v1/artists/2DtIt7mMzdaEEFVUbSmnoU'},
#  {'artist_id': '1Sdc6ySbIvzO0X9vbyHzWm',
#   'artist_name': 'Ogryzek',
#   'external_url': 'https://api.spotify.com/v1/artists/1Sdc6ySbIvzO0X9vbyHzWm'},
#  {'artist_id': '19P1EvDdYzg1ICEyiAEk4m',
#   'artist_name': 'DJ BRYAN 7',
#   'external_url': 'https://api.spotify.com/v1/artists/19P1EvDdYzg1ICEyiAEk4m'},
#  {'artist_id': '4ziGmZKhRvzoP0De6vcXGt',
#   'artist_name': 'DJIEGO',
#   'external_url': 'https://api.spotify.com/v1/artists/4ziGmZKhRvzoP0De6vcXGt'},
#  {'artist_id': '12PDaXrPNMYQsQLnSnDaSS',
#   'artist_name': 'Maxximo Dj',
#   'external_url': 'https://api.spotify.com/v1/artists/12PDaXrPNMYQsQLnSnDaSS'},
#  {'artist_id': '1Z7oSc1PMSULPIoKwUlyb4',
#   'artist_name': 'Mc M4',
#   'external_url': 'https://api.spotify.com/v1/artists/1Z7oSc1PMSULPIoKwUlyb4'},
#  {'artist_id': '5joODcLQTClX0o3q13SOfU',
#   'artist_name': 'RXPOSO99',
#   'external_url': 'https://api.spotify.com/v1/artists/5joODcLQTClX0o3q13SOfU'},
#  {'artist_id': '3l4fsEzoeabsET7ddv0lZW',
#   'artist_name': 'Mc Delux',
#   'external_url': 'https://api.spotify.com/v1/artists/3l4fsEzoeabsET7ddv0lZW'},
#  {'artist_id': '0T82thOoh3ksJmLJv4EvP8',
#   'artist_name': 'dawnicy',
#   'external_url': 'https://api.spotify.com/v1/artists/0T82thOoh3ksJmLJv4EvP8'},
#  {'artist_id': '4hV3aU0WKvFaiX5ugXP5hp',
#   'artist_name': 'MC MN',
#   'external_url': 'https://api.spotify.com/v1/artists/4hV3aU0WKvFaiX5ugXP5hp'},
#  {'artist_id': '4C5EDmZfgkkSwUVFSvuUNP',
#   'artist_name': 'Anar',
#   'external_url': 'https://api.spotify.com/v1/artists/4C5EDmZfgkkSwUVFSvuUNP'},
#  {'artist_id': '4DWPOsGWbW7sBHb1UuBvWs',
#   'artist_name': 'Polaris',
#   'external_url': 'https://api.spotify.com/v1/artists/4DWPOsGWbW7sBHb1UuBvWs'},
#  {'artist_id': '21zPGluD0MD68ctSgkuMXi',
#   'artist_name': 'DJ Ikeraus',
#   'external_url': 'https://api.spotify.com/v1/artists/21zPGluD0MD68ctSgkuMXi'},
#  {'artist_id': '5lfW7OqzTLDhvIcHFpxFDB',
#   'artist_name': 'MC FERNANDINHO FN',
#   'external_url': 'https://api.spotify.com/v1/artists/5lfW7OqzTLDhvIcHFpxFDB'},
#  {'artist_id': '648ZoUpTM6iIMTCgo3lLCE',
#   'artist_name': 'DJ Paulinho Mondi Da Baixa Baviera',
#   'external_url': 'https://api.spotify.com/v1/artists/648ZoUpTM6iIMTCgo3lLCE'},
#  {'artist_id': '0sjGfRBmq6lKmUNgt8Ptic',
#   'artist_name': 'Mc Vitorioso',
#   'external_url': 'https://api.spotify.com/v1/artists/0sjGfRBmq6lKmUNgt8Ptic'},
#  {'artist_id': '14xRX3JR8H4RWh8R7V3fvZ',
#   'artist_name': 'Miguel Angeles',
#   'external_url': 'https://api.spotify.com/v1/artists/14xRX3JR8H4RWh8R7V3fvZ'},
#  {'artist_id': '09cKncAQn28NqTUORLMwSR',
#   'artist_name': 'Ariis',
#   'external_url': 'https://api.spotify.com/v1/artists/09cKncAQn28NqTUORLMwSR'},
#  {'artist_id': '6JjQbtAO09K7qBEW2pdX5s',
#   'artist_name': 'isq',
#   'external_url': 'https://api.spotify.com/v1/artists/6JjQbtAO09K7qBEW2pdX5s'},
#  {'artist_id': '7qIgmxSjoXEeifSVDh8nIt',
#   'artist_name': 'MXCCREE',
#   'external_url': 'https://api.spotify.com/v1/artists/7qIgmxSjoXEeifSVDh8nIt'},
#  {'artist_id': '1dX1zejt24Ojiu0lX4T1ZM',
#   'artist_name': 'DJ GL3CHEKY',
#   'external_url': 'https://api.spotify.com/v1/artists/1dX1zejt24Ojiu0lX4T1ZM'},
#  {'artist_id': '62D4KEvQMmmK88mTkkWx6Q',
#   'artist_name': 'RD12',
#   'external_url': 'https://api.spotify.com/v1/artists/62D4KEvQMmmK88mTkkWx6Q'},
#  {'artist_id': '5IpS1TN1Crp8Ym4zjiIrtK',
#   'artist_name': 'LXNGVX',
#   'external_url': 'https://api.spotify.com/v1/artists/5IpS1TN1Crp8Ym4zjiIrtK'},
#  {'artist_id': '5Vd9shhZpzTYaaZ6KQNnjU',
#   'artist_name': 'GLXXMSTRIDER',
#   'external_url': 'https://api.spotify.com/v1/artists/5Vd9shhZpzTYaaZ6KQNnjU'},
#  {'artist_id': '5WqZHtRzOmKc1hWYfNoo8n',
#   'artist_name': 'TOKYOPHILE',
#   'external_url': 'https://api.spotify.com/v1/artists/5WqZHtRzOmKc1hWYfNoo8n'},
#  {'artist_id': '1cCYuIofJkQf9YN1FZo5A4',
#   'artist_name': 'DJ OLIVEIRA ORIGINAL',
#   'external_url': 'https://api.spotify.com/v1/artists/1cCYuIofJkQf9YN1FZo5A4'},
#  {'artist_id': '44AXaX2aJKSQhMxVTtNb0s',
#   'artist_name': 'Mc Koruja',
#   'external_url': 'https://api.spotify.com/v1/artists/44AXaX2aJKSQhMxVTtNb0s'},
#  {'artist_id': '2vKxv2oKVSEJZ1VmuLUOvY',
#   'artist_name': 'Irokz',
#   'external_url': 'https://api.spotify.com/v1/artists/2vKxv2oKVSEJZ1VmuLUOvY'},
#  {'artist_id': '6OwbqUSj4XbZdjexPsKkdH',
#   'artist_name': 'PXLWYSE',
#   'external_url': 'https://api.spotify.com/v1/artists/6OwbqUSj4XbZdjexPsKkdH'},
#  {'artist_id': '1Sdc6ySbIvzO0X9vbyHzWm',
#   'artist_name': 'Ogryzek',
#   'external_url': 'https://api.spotify.com/v1/artists/1Sdc6ySbIvzO0X9vbyHzWm'},
#  {'artist_id': '0oGN0s7dqyWbR41yMsNs0R',
#   'artist_name': 'princce',
#   'external_url': 'https://api.spotify.com/v1/artists/0oGN0s7dqyWbR41yMsNs0R'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id               name release_date  total_tracks  \
# 0  6DptPhwLku8xvWBodULnC6  Orquestra Maldita   2023-06-15             1
# 1  0ZE5fMneYtdl93X1GHqxSH           BYE BYE!   2024-01-12             3
# 2  2EuOCirl08WxbRY2cfj4H5        Life in Rio   2023-03-17             1
# 3  1mAU33mqJDs4eekzZAQZvf  Kerosene (Slowed)   2022-12-10             1
# 4  5rDznSixlUXNxJySfWQNb7      REI DO BRASIL   2023-06-02             1
#
#                                                  url
# 0  https://open.spotify.com/album/6DptPhwLku8xvWB...
# 1  https://open.spotify.com/album/0ZE5fMneYtdl93X...
# 2  https://open.spotify.com/album/2EuOCirl08WxbRY...
# 3  https://open.spotify.com/album/1mAU33mqJDs4eek...
# 4  https://open.spotify.com/album/5rDznSixlUXNxJy...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      55 non-null     object
#  1   name          55 non-null     object
#  2   release_date  55 non-null     object
#  3   total_tracks  55 non-null     int64
#  4   url           55 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.3+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id          song_name  duration_ms  \
# 0  7hcagAQDiI0TgUOv337NIr  Orquestra Maldita       119777
# 1  17Nc99PG4IF49K5H8uNEQi           BYE BYE!       112000
# 2  7vtGOauV0Zz8Px5EJYm7d7        Life in Rio        94418
# 3  2weO22kObPnyX1jKQStb40  Kerosene - Slowed       142105
# 4  6Seth37t5I69wFbuGFrsiG      REI DO BRASIL        97846
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/7hcagAQDiI0TgUO...          72
# 1  https://open.spotify.com/track/17Nc99PG4IF49K5...          57
# 2  https://open.spotify.com/track/7vtGOauV0Zz8Px5...          70
# 3  https://open.spotify.com/track/2weO22kObPnyX1j...          68
# 4  https://open.spotify.com/track/6Seth37t5I69wFb...          66
#
#              song_added                album_id               artist_id
# 0  2024-02-23T14:40:21Z  6DptPhwLku8xvWBodULnC6  3rt96VXGtEgD4uSOJ6B69H
# 1  2024-02-23T14:51:11Z  0ZE5fMneYtdl93X1GHqxSH  5sj3P8OH8O5aVmey1C2mf4
# 2  2024-02-24T05:40:13Z  2EuOCirl08WxbRY2cfj4H5  65FHTCI8EmW94W0TdWb8ja
# 3  2024-02-24T05:42:05Z  1mAU33mqJDs4eekzZAQZvf  5L9XA5GDsOOKNZfeOO8lmo
# 4  2024-02-24T05:46:58Z  5rDznSixlUXNxJySfWQNb7  3qycxIGAHj1KyoAQ6PGCO6

# %%
artist_df.head()
# Out:
#                 artist_id  artist_name  \
# 0  5YGY8feqx7naU7z4HrwZM6  Miley Cyrus
# 1  7tYKF4w9nC0nq9CsPZTHyP          SZA
# 2  716NhGYqD1jl2wI1Qkgq36     Bizarrap
# 3  0EmeFodog0BfCgMzAIvKQp      Shakira
# 4  2wY79sveU1sp5g7SokKOiI    Sam Smith
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/5YGY8feqx7n...
# 1  https://api.spotify.com/v1/artists/7tYKF4w9nC0...
# 2  https://api.spotify.com/v1/artists/716NhGYqD1j...
# 3  https://api.spotify.com/v1/artists/0EmeFodog0B...
# 4  https://api.spotify.com/v1/artists/2wY79sveU1s...

# %%
album_df.head()
# Out:
#                  album_id                                   name release_date  \
# 0  7I0tjwFtxUwBC1vgyeMAax                                Flowers   2023-01-13
# 1  1nrVofqDRs7cpWXJ49qTnP                                    SOS   2022-12-08
# 2  1gi2iwr1l8IUyHYHxi01pg  Shakira: Bzrp Music Sessions, Vol. 53   2023-01-11
# 3  3Uq1jNGnD412ZvCb6j2DKV                                 Gloria   2023-01-27
# 4  7txGsnDSqVMoRl6RQ9XyZP                      HEROES & VILLAINS   2022-12-02
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/7I0tjwFtxUwBC1v...
# 1            23  https://open.spotify.com/album/1nrVofqDRs7cpWX...
# 2             1  https://open.spotify.com/album/1gi2iwr1l8IUyHY...
# 3            13  https://open.spotify.com/album/3Uq1jNGnD412ZvC...
# 4            15  https://open.spotify.com/album/7txGsnDSqVMoRl6...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
